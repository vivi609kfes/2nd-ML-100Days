# %% [markdown]
# # 作業目標:
#     寫出 ReLU & dReLU 一階導數
#     並列印

# %% [markdown]
# # 作業重點
#
# # Rectified Linear Unit- Relu
#
# f(x)=max(0,x)

# %%
import numpy as np
from numpy import *
import matplotlib.pylab as plt
# %matplotlib inline

'''
作業:
    寫出 ReLU & dReLU 一階導數
    並列印
'''
# Out:
# '\n作業:\n    寫出 ReLU & dReLU 一階導數\n    並列印\n'

# %%
def ReLU(x):
    return abs(x)*(x>0)
    
def dReLU(x):
    return (1*(x>0))

# %%
##linspace
## 在-10 to 10 中間放100個等差數列
x=plt.linspace(-10,10,100)

# %%
plt.plot(x,ReLU(x),'r')
plt.text(6, 8, r'$f(x)=max(0,x)$', fontsize=15)
plt.plot(x,dReLU(x),'b')
plt.text(6, 2, 'x < 0 ,x = 0')
plt.text(6, 1.5, 'x >= 0 ,x = 1')
# Out:
# Text(6, 1.5, 'x >= 0 ,x = 1')
